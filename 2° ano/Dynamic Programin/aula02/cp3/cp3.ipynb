# %%
lista = [38, 12, 44, 27, 9]

# %%
aux = 0
contador = 1
contadorTroca = 1
for i in range(len(lista)):
    for j in range(len(lista)):
        if lista[i] < lista[j]:
            aux = lista[i]
            lista[i] = lista[j] 
            lista[j] = aux
            print(f"{contadorTroca}° Troca de {lista[i]} por {lista[j]}")
            contadorTroca += 1
        print(f"{contador}° Etapa: {lista}")
        contador += 1
print(f"Total de comparações: {contador}")
print(f"Total de trocas realizadas: {contadorTroca}")
# Out:
# 1° Etapa: [38, 12, 44, 27, 9]
# 2° Etapa: [38, 12, 44, 27, 9]
# 1° Troca de 44 por 38
# 3° Etapa: [44, 12, 38, 27, 9]
# 4° Etapa: [44, 12, 38, 27, 9]
# 5° Etapa: [44, 12, 38, 27, 9]
# 2° Troca de 44 por 12
# 6° Etapa: [12, 44, 38, 27, 9]
# 7° Etapa: [12, 44, 38, 27, 9]
# 8° Etapa: [12, 44, 38, 27, 9]
# 9° Etapa: [12, 44, 38, 27, 9]
# 10° Etapa: [12, 44, 38, 27, 9]
# 11° Etapa: [12, 44, 38, 27, 9]
# 3° Troca de 44 por 38
# 12° Etapa: [12, 38, 44, 27, 9]
# 13° Etapa: [12, 38, 44, 27, 9]
# 14° Etapa: [12, 38, 44, 27, 9]
# 15° Etapa: [12, 38, 44, 27, 9]
# 16° Etapa: [12, 38, 44, 27, 9]
# 4° Troca de 38 por 27
# 17° Etapa: [12, 27, 44, 38, 9]
# 5° Troca de 44 por 38
# 18° Etapa: [12, 27, 38, 44, 9]
# 19° Etapa: [12, 27, 38, 44, 9]
# 20° Etapa: [12, 27, 38, 44, 9]
# 6° Troca de 12 por 9
# 21° Etapa: [9, 27, 38, 44, 12]
# 7° Troca de 27 por 12
# 22° Etapa: [9, 12, 38, 44, 27]
# 8° Troca de 38 por 27
# 23° Etapa: [9, 12, 27, 44, 38]
# 9° Troca de 44 por 38
# 24° Etapa: [9, 12, 27, 38, 44]
# ...

# %%
aux = 1
def mergeSort(lista):
    global aux
    if len(lista) > 1:
        meio = len(lista)//2


        esq = lista[:meio]
        dir = lista[meio:]
        print(f'esquerda: {esq}, direita: {dir}')


        mergeSort(esq)
        mergeSort(dir)

        i=0
        j=0
        k=0
        while i < len(esq) and j < len(dir):     
            print(f'Etapa: {aux}')
            
            if esq[i] < dir[j]:
                print(f"Troca: {lista[k]} por {esq[i]}")
                lista[k]=esq[i]
                i=i+1
            else:
                print(f"Troca: {lista[k]} por {dir[i]}")
                lista[k]=dir[j]
                j =j+1
            k=k+1
            aux += 1
        while i < len(esq):
            print(f'Etapa: {aux}')   
            print(f"mescla: {esq[i]}")
            lista[k]=esq[i]
            i=i+1
            k=k+1
            aux += 1
        while j < len(dir):
            print(f'Etapa: {aux}')
            print(f"mescla: {dir[j]}")
            lista[k]=dir[j]
            j=j+1
            k=k+1
            aux += 1

lista = [38, 12, 44, 27, 9]
mergeSort(lista)
print(f"Lista final: {lista}")
# Out:
# esquerda: [38, 12], direita: [44, 27, 9]
# esquerda: [38], direita: [12]
# Etapa: 1
# Troca: 38 por 12
# Etapa: 2
# mescla: 38
# esquerda: [44], direita: [27, 9]
# esquerda: [27], direita: [9]
# Etapa: 3
# Troca: 27 por 9
# Etapa: 4
# mescla: 27
# Etapa: 5
# Troca: 44 por 9
# Etapa: 6
# Troca: 27 por 9
# Etapa: 7
# mescla: 44
# Etapa: 8
# Troca: 38 por 9
# Etapa: 9
# Troca: 12 por 12
# Etapa: 10
# Troca: 44 por 27
# Etapa: 11
# Troca: 27 por 38
# Etapa: 12
# mescla: 44
# Lista final: [9, 12, 27, 38, 44]
